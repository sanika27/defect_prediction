# %%
# importing pandas
import pandas as pd

#fetch data and add headers
filepath = 'dataset_processed_01.csv'
column = ['complexity','token_count','loc','lloc','sloc','comments',
          'multi','blank','code_comment','h1','h2','N1','N2','vocabulary','length',
          'calculated_length','volume', 'difficulty','effort','time','bugs','defect']

df = pd.read_csv(filepath, index_col=False, usecols = column)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-a107125c0c7c> in <module>
#       1 # importing pandas
# ----> 2 import pandas as pd
#       3
#       4 #fetch data and add headers
#       5 filepath = 'dataset_processed_01.csv'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat.numpy import (
#      23     _np_version_under1p14,
#      24     _np_version_under1p15,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/compat/numpy/__init__.py in <module>
#       7
#       8 # numpy versioning
# ----> 9 _np_version = np.__version__
#      10 _nlv = LooseVersion(_np_version)
#      11 _np_version_under1p14 = _nlv < LooseVersion("1.14")
#
# AttributeError: module 'numpy' has no attribute '__version__'

# %%
df
# Out:
#        complexity  token_count   loc  lloc  sloc  comments  multi  blank  \
# 0              19          473   182   127   129         0      0     53
# 1              19          473  1165   710   800        67    119    181
# 2              12          234  1392   870  1177        35     17    170
# 3              62         1372   773   419   590        28      0    166
# 4              62         1372   421   273   302        44     34     57
# ...           ...          ...   ...   ...   ...       ...    ...    ...
# 42859         119         3209  1523   757  1297        19     12    193
# 42860         119         3209   701   378   504        33     58    109
# 42861         124         3511    77    34    69         0      0      8
# 42862         124         3511   712   438   573        51      9     84
# 42863           5          319    77    34    69         0      0      8
#
#        code_comment  h1  ...   N2  vocabulary  length  calculated_length  \
# 0               182   5  ...   42          44      63                217
# 1              1232  18  ...  282         261     435               2000
# 2              1427  14  ...  531         508     811               4473
# 3               801  10  ...  217         214     330               1598
# 4               465  17  ...  107          98     166                583
# ...             ...  ..  ...  ...         ...     ...                ...
# 42859          1542  12  ...  230         205     347               1508
# 42860           734  13  ...  126         123     194                794
# 42861            77   3  ...   29          27      45                114
# 42862           763  14  ...  128         116     199                733
# 42863            77   3  ...   29          27      45                114
#
#        volume  difficulty  effort  time  bugs  defect
# 0         343           2     926    51     0       1
# 1        3492          10   36473  2026     1       1
# 2        7289           7   54850  3047     2       1
# 3        2554           5   13587   754     0       1
# 4        1098          11   12329   684     0       1
# ...       ...         ...     ...   ...   ...     ...
# 42859    2664           7   19053  1058     0       0
# 42860    1346           7   10027   557     0       0
# 42861     213           1     387    21     0       0
# 42862    1364           8   11988   666     0       0
# 42863     213           1     387    21     0       0
#
# [42864 rows x 22 columns]

# %%
# dropiing the duplicate rows but keeping the first row that has a duplicate below in the dataset
df.drop_duplicates(keep='first', inplace=True)
df
# Out:
#        complexity  token_count   loc  lloc  sloc  comments  multi  blank  \
# 0              19          473   182   127   129         0      0     53
# 1              19          473  1165   710   800        67    119    181
# 2              12          234  1392   870  1177        35     17    170
# 3              62         1372   773   419   590        28      0    166
# 4              62         1372   421   273   302        44     34     57
# ...           ...          ...   ...   ...   ...       ...    ...    ...
# 42851          69         1502   402   202   227        24     74     80
# 42852          65         2178    53    23    39         0      0     13
# 42853          65         2178   515   298   307        33     80     99
# 42854         294         6567    72    33    56         0      4     12
# 42855         294         6567  1454   835  1044        76    110    219
#
#        code_comment  h1  ...   N2  vocabulary  length  calculated_length  \
# 0               182   5  ...   42          44      63                217
# 1              1232  18  ...  282         261     435               2000
# 2              1427  14  ...  531         508     811               4473
# 3               801  10  ...  217         214     330               1598
# 4               465  17  ...  107          98     166                583
# ...             ...  ..  ...  ...         ...     ...                ...
# 42851           426  12  ...   61          64      94                339
# 42852            53   2  ...    8          10      12                 26
# 42853           548  12  ...   77          75     121                419
# 42854            72   1  ...    1           2       2                  0
# 42855          1530  17  ...  296         292     454               2297
#
#        volume  difficulty  effort  time  bugs  defect
# 0         343           2     926    51     0       1
# 1        3492          10   36473  2026     1       1
# 2        7289           7   54850  3047     2       1
# 3        2554           5   13587   754     0       1
# 4        1098          11   12329   684     0       1
# ...       ...         ...     ...   ...   ...     ...
# 42851     564           7    3969   220     0       0
# 42852      39           1      39     2     0       0
# 42853     753           7    5527   307     0       0
# 42854       2           0       1     0     0       0
# 42855    3718           9   34017  1889     1       0
#
# [20052 rows x 22 columns]

# %%
#remove rows where LOC = 0, and complexity = 0
col = ['complexity','loc']
df = df.replace(0, pd.np.nan).dropna(axis=0,how='any',subset=col).fillna(0).astype(int)
df
# Out:
#        complexity  token_count   loc  lloc  sloc  comments  multi  blank  \
# 0              19          473   182   127   129         0      0     53
# 1              19          473  1165   710   800        67    119    181
# 2              12          234  1392   870  1177        35     17    170
# 3              62         1372   773   419   590        28      0    166
# 4              62         1372   421   273   302        44     34     57
# ...           ...          ...   ...   ...   ...       ...    ...    ...
# 42851          69         1502   402   202   227        24     74     80
# 42852          65         2178    53    23    39         0      0     13
# 42853          65         2178   515   298   307        33     80     99
# 42854         294         6567    72    33    56         0      4     12
# 42855         294         6567  1454   835  1044        76    110    219
#
#        code_comment  h1  ...   N2  vocabulary  length  calculated_length  \
# 0               182   5  ...   42          44      63                217
# 1              1232  18  ...  282         261     435               2000
# 2              1427  14  ...  531         508     811               4473
# 3               801  10  ...  217         214     330               1598
# 4               465  17  ...  107          98     166                583
# ...             ...  ..  ...  ...         ...     ...                ...
# 42851           426  12  ...   61          64      94                339
# 42852            53   2  ...    8          10      12                 26
# 42853           548  12  ...   77          75     121                419
# 42854            72   1  ...    1           2       2                  0
# 42855          1530  17  ...  296         292     454               2297
#
#        volume  difficulty  effort  time  bugs  defect
# 0         343           2     926    51     0       1
# 1        3492          10   36473  2026     1       1
# 2        7289           7   54850  3047     2       1
# 3        2554           5   13587   754     0       1
# 4        1098          11   12329   684     0       1
# ...       ...         ...     ...   ...   ...     ...
# 42851     564           7    3969   220     0       0
# 42852      39           1      39     2     0       0
# 42853     753           7    5527   307     0       0
# 42854       2           0       1     0     0       0
# 42855    3718           9   34017  1889     1       0
#
# [20052 rows x 22 columns]

# %%
#writing release filter labelled data to CSV
df.to_csv('dataset_processed_01.csv',index=False)

# %%
df.dtypes
# Out:
# complexity           int64
# token_count          int64
# loc                  int64
# lloc                 int64
# sloc                 int64
# comments             int64
# multi                int64
# blank                int64
# code_comment         int64
# h1                   int64
# h2                   int64
# N1                   int64
# N2                   int64
# vocabulary           int64
# length               int64
# calculated_length    int64
# volume               int64
# difficulty           int64
# effort               int64
# time                 int64
# bugs                 int64
# defect               int64
# dtype: object

# %%
X = df.iloc[:,0:-1] #features
y = df.iloc[:,-1] #labels

# %%
#divide dataset into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=None)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-fe018492c830> in <module>
#       1 #divide dataset into train and test
# ----> 2 from sklearn.model_selection import train_test_split
#       3
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=None)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/__init__.py in <module>
#      17 from ._split import check_cv
#      18
# ---> 19 from ._validation import cross_val_score
#      20 from ._validation import cross_val_predict
#      21 from ._validation import cross_validate
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in <module>
#      29 from ..utils._joblib import logger
#      30 from ..externals.six.moves import zip
# ---> 31 from ..metrics.scorer import check_scoring, _check_multimetric_scoring
#      32 from ..exceptions import FitFailedWarning
#      33 from ._split import check_cv
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/__init__.py in <module>
#      32 from .classification import brier_score_loss
#      33
# ---> 34 from . import cluster
#      35 from .cluster import adjusted_mutual_info_score
#      36 from .cluster import adjusted_rand_score
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/__init__.py in <module>
#      18 from .supervised import fowlkes_mallows_score
#      19 from .supervised import entropy
# ---> 20 from .unsupervised import silhouette_samples
#      21 from .unsupervised import silhouette_score
#      22 from .unsupervised import calinski_harabaz_score
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py in <module>
#      15 from ...utils import check_X_y
#      16 from ...utils import safe_indexing
# ---> 17 from ..pairwise import pairwise_distances_chunked
#      18 from ..pairwise import pairwise_distances
#      19 from ...preprocessing import LabelEncoder
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in <module>
#      29 from ..utils._joblib import effective_n_jobs
#      30
# ---> 31 from .pairwise_fast import _chi2_kernel_fast, _sparse_manhattan
#      32
#      33
#
# ImportError: dlopen(/Users/sanika/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise_fast.cpython-36m-darwin.so, 2): Library not loaded: @rpath/libopenblas.dylib
#   Referenced from: /Users/sanika/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise_fast.cpython-36m-darwin.so
#   Reason: image not found

# %%
# model for Gausian NB
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_train, y_train)
#predict model on test data
predicted = gnb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-08b6920e7902> in <module>
#       1 # model for Gausian NB
#       2 from sklearn.naive_bayes import GaussianNB
# ----> 3 gnb = GaussianNB().fit(X_train, y_train)
#       4 #predict model on test data
#       5 predicted = gnb.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
#get accuracy, precision, recall
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

accuracy_score = accuracy_score(y_test,predicted)
precision_score = precision_score(y_test,predicted)
recall_score = recall_score(y_test,predicted)
print("Accuracy:",accuracy_score)
print("Precision:",precision_score)
print("Recall:",recall_score)
# Out:
# Accuracy: 0.567185069984448
# Precision: 0.32629727352682497
# Recall: 0.37230306071249375

# %%
#LogisticRegression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_train)
# print('Train accuracy score:',accuracy_score(y_train,y_pred))
# print('Test accuracy score:', accuracy_score(y_test,logreg.predict(X_test)))

#get accuracy, precision, recall
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

accuracy_score = accuracy_score(y_test,predicted)
precision_score = precision_score(y_test,predicted)
recall_score = recall_score(y_test,predicted)
print("Accuracy:",accuracy_score)
print("Precision:",precision_score)
print("Recall:",recall_score)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-21f2f4ec2674> in <module>
#       1 #LogisticRegression
#       2
# ----> 3 from sklearn.linear_model import LogisticRegression
#       4 from sklearn.metrics import accuracy_score
#       5 logreg = LogisticRegression()
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/__init__.py in <module>
#      13
#      14 from .bayes import BayesianRidge, ARDRegression
# ---> 15 from .least_angle import (Lars, LassoLars, lars_path, LarsCV, LassoLarsCV,
#      16                           LassoLarsIC)
#      17 from .coordinate_descent import (Lasso, ElasticNet, LassoCV, ElasticNetCV,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py in <module>
#      21 from .base import LinearModel
#      22 from ..base import RegressorMixin
# ---> 23 from ..utils import arrayfuncs, as_float_array, check_X_y, deprecated
#      24 from ..model_selection import check_cv
#      25 from ..exceptions import ConvergenceWarning
#
# ImportError: dlopen(/Users/sanika/anaconda3/lib/python3.6/site-packages/sklearn/utils/arrayfuncs.cpython-36m-darwin.so, 2): Library not loaded: @rpath/libopenblas.dylib
#   Referenced from: /Users/sanika/anaconda3/lib/python3.6/site-packages/sklearn/utils/arrayfuncs.cpython-36m-darwin.so
#   Reason: image not found

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier as RFC
rfc_b = RFC()
rfc_b.fit(X_train,y_train)
y_pred = rfc_b.predict(X_train)
print('Train accuracy score:',accuracy_score(y_train,y_pred))
print('Test accuracy score:', accuracy_score(y_test,rfc_b.predict(X_test)))
# Out:
# /Users/sanika/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# Train accuracy score: 0.8354284459570731
# Test accuracy score: 0.6954898911353032

# %%
# KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_train)
print('Train accuracy score:',accuracy_score(y_train,y_pred))
print('Test accuracy score:',accuracy_score(y_test,knn.predict(X_test)))
# Out:
# Train accuracy score: 0.7872866004281714
# Test accuracy score: 0.7255054432348367

# %%
#APPROACH 2 - FEATURE SELECTION (Univariate Selection)
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

X = df1.iloc[:,0:-1] #features
y = df1.iloc[:,-1] #labels

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['features','score']  #naming the dataframe columns
print(featureScores.nlargest(10,'score'))  #print 10 best features
# Out:
#         features          score
# 1    token_count  319528.646683
# 0     complexity    7788.461848
# 6          multi    2333.753862
# 8   code_comment    1909.983326
# 2            loc    1866.380124
# 3           lloc    1762.407609
# 18        effort    1629.977633
# 7          blank    1617.318176
# 4           sloc    1348.509156
# 19          time    1296.774022

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.20.1
